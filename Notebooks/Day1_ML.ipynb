# %%
import numpy as np
import pandas as pd
import requests
import seaborn as sns
import matplotlib.pyplot as plt

# %%
url = "https://real-time-news-data.p.rapidapi.com/search"

querystring = {"query":"Football","limit":"10","time_published":"anytime","country":"US","lang":"en"}

headers = {
	"x-rapidapi-key": "0ba8f44865mshe338c4d7b993b95p1e1b21jsn04b94b1d069e",
	"x-rapidapi-host": "real-time-news-data.p.rapidapi.com",
	"Content-Type": "application/json"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'status': 'OK', 'request_id': 'a478ea4d-8648-4003-a13e-495d84aacda1', 'data': [{'article_id': '', 'title': 'Tom Brady would "never say never" to playing Olympic flag football in 2028', 'link': 'https://www.nbcsports.com/nfl/profootballtalk/rumor-mill/news/tom-brady-would-never-say-never-to-playing-olympic-flag-football-in-2028', 'snippet': 'This weekend, Tom Brady will participate in a flag football tournament. It could be a precursor to participating in a bigger event two years\xa0...', 'photo_url': 'https://nbcsports.brightspotcdn.com/dims4/default/6506ba2/2147483647/strip/false/crop/5000x3334+0+0/resize/1486x991!/quality/90/?url=https%3A%2F%2Fnbc-sports-production-nbc-sports.s3.us-east-1.amazonaws.com%2Fbrightspot%2F37%2Fb6%2F5290ff654cc88b359e55d433b16d%2Fhttps-delivery-gettyimages.com%2Fdownloads%2F2261984221', 'thumbnail_url': 'https://news.google.com/api/attachments/CC8iK0NnNUdkVWR2VWtKc1EySTBSRXBhVFJDM0FSaVRBaWdCTWdZbGRZenNNUVk=-w200-h200-p-df-rw', 'published_datetime_utc': '2026-03-19T03:19:04.000Z', 'authors': ['Mike Florio'], 'source_url': 'https://www.nbcsports.com', 'source_name': 'NBC Sports', 'source_logo_url': 'https://encrypted-tbn1.gstatic.com/faviconV2?url=https://www.nbcsports.com&client=NEWS_360&size=256&type=FAVICON&fallback_opts=TYPE,SIZE,URL', 'source_favicon_url': 'https://encrypted-tbn1.gstatic.com/faviconV2?url=https://www.nbcsports.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL', 'source_publication_id': 'CAAqKAgKIiJDQklTRXdnTWFnOEtEVzVpWTNOd2IzSjBjeTVqYjIwb0FBUAE', 'related_topics': [{'topic_id': 'CAAqJAgKIh5DQkFTRUFvS0wyMHZNSGszYzNab2JCSUNaVzRvQUFQAQ', 'topic_name': 'Mike Florio'}], 'sub_articles': [{'article_id': 'CBMisgFBVV95cUxPczhNVDNwMDl1MjlkM0FpZkdvOFIzWVVleDgzWXlISndEQ3hjam45blE4TmN0b2Zmc0xqcVFKMDM5bWpoYmtzam1NRnBmYVBBRG5JN19mSVpaX2ZXMGtxZjBzN1Zvd3ItYzdPQWhhTlFaemNFa2J6LWZrQ1pMRElJYThUSmJvUmplWjlGQkxqMV90N1dHem9lWUdveVFfdFdBd3pxdzEyY0ZnSW5mY2hJYUFn', 'title': 'Fanatics Flag Football Classic rosters are out. See who Tom Brady drafted', 'link': 'https://www.usatoday.com/story/sports/nfl/2026/03/19/fanatics-flag-football-classic-draft-tom-brady/89216268007/', 'photo_url': 'https://www.usatoday.com/gcdn/authoring/authoring-images/2026/03/18/USAT/89216690007-tom-brady-joe-burrow-imagn.jpg?crop=3993,2248,x0,y204&width=660&height=371&format=pjpg&auto=webp', 'thumbnail_url': 'https://news.google.com/api/attachments/CC8iK0NnNUZkVk5TTmxSeVp6ZzRVa3hMVFJEekFoaVVCU2dLTWdZQkVKS29tQW8=-w200-h200-p-df-rw', 'published_datetime_utc': '2026-03-19T17:31:00.000Z', 'authors': ['Jack Mckessy'], 'source_url': 'https://www.usatoday.com', 'source_name': 'USA Today', 'source_logo_url': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://www.usatoday.com&client=NEWS_360&size=256&type=FAVICON&fallback_opts=TYPE,SIZE,URL', 'source_favicon_url': 'https://encrypted-tbn0.gstatic.com/faviconV2?url=https://www.usatoday.com&client=NEWS_360&size=96&type=FAVICON&fallback_opts=TYPE,SIZE,URL', 'source_publication_id': 'CAAqJggKIiBDQklTRWdnTWFnNEtESFZ6WVhSdlpHRjVMbU52YlNnQVAB', 'related_topics': [{'topic_id': 'CAAqKAgKIiJDQkFTRXdvTkwyY3ZNVEZuYUhZM1oyZHVjQklDWlc0b0FBUAE', 'topic_name': 'Jack Mckessy'}]}, {'article_id': '', 'title': 'Harrison Smith replaces Derwin James Jr. in flag football tournament', 'link': 'https://www.nbcsports.com/nfl/profootballtalk/rumor-mill/news/harrison-smith-replaces-derwin-james-jr-in-flag-football-tournament', 'photo_url': 'ht ...

# %%
import pandas as pd

df1 = pd.DataFrame(response)
# df.head()
df1
# Out:
#                                                      0
# 0    b'{"status":"OK","request_id":"a478ea4d-8648-4...
# 1    b'c2bWktVXY4WmFfT2c4bklKSVhvSVhXU09VR3RqVWRTMT...
# 2    b'k2Q3FHYURGeGFEemRnbXdwNllMa1RTUWtJLXFEVENfM2...
# 3    b'Tom Brady would \\"never say never\\" to pla...
# 4    b'alk/rumor-mill/news/tom-brady-would-never-sa...
# ..                                                 ...
# 162  b'dLTWdhSkVaRFVIQWs=-w200-h200-p-df-rw","publi...
# 163  b'.dawgnation.com","source_name":"DawgNation",...
# 164  b'nation.com&client=NEWS_360&size=256&type=FAV...
# 165  b'ic.com/faviconV2?url=https://www.dawgnation....
# 166  b'ation_id":"CAAqKQgKIiNDQklTRkFnTWFoQUtEbVJoZ...
#
# [167 rows x 1 columns]

# %%
df = pd.read_csv("train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
sns.countplot(x=df["Pclass"])
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
df["Survived"].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df["Survived"].value_counts().plot(kind = "pie", autopct="%.2f")
# Out:
# <Axes: >

# %% [markdown]
# **Numerical Data**

# %%
#Histogram
plt.hist(df["Age"])
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
#Displot
sns.histplot(df["Age"], kde=True, bins=9)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.boxplot(x=df["Fare"])
# Out:
# <Axes: xlabel='Fare'>
